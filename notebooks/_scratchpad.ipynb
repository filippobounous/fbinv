# %%
import datetime
import pandas as pd
import sys

sys.path.append('..')

# %%
from investment.core.portfolio import Portfolio
from investment.core.transactions import Transactions

# %%
# Transactions().update() # get latest data

# %%
df = Portfolio().portfolio

# %%
p = Portfolio()

# %%
df.as_of_date == datetime.datetime
# Out:
#     as_of_date          code   quantity    avg_price currency         value
# 0   03/05/2020     AFHOLDING     1.0000  1138.000000      EUR  1.000000e+00
# 1   13/02/2024  GB00B5B71Q71     4.5354   881.960000      GBP  2.056985e+01
# 2   06/06/2024  GB00B5B71Q71     8.8589   903.453294      GBP  7.848011e+01
# 3   18/08/2023  GB00BL6L0369   716.2140     0.934400      GBP  5.129625e+05
# 4   26/09/2023  GB00BL6L0369  1030.4490     0.940590      GBP  1.061825e+06
# 5   13/11/2023  GB00BL6L0369  1345.1090     0.943594      GBP  1.809318e+06
# 6   24/11/2023  GB00BL6L0369  1669.9850     0.948653      GBP  2.788850e+06
# 7   08/01/2024  GB00BL6L0369  1987.1100     0.955778      GBP  3.948606e+06
# 8   31/01/2024  GB00BL6L0369  2295.8730     0.964442      GBP  5.271033e+06
# 9   20/02/2024  GB00BL6L0369  2599.4580     0.972986      GBP  6.757182e+06
# 10  05/04/2024  GB00BL6L0369  2894.5680     0.982612      GBP  8.378524e+06
# ...
